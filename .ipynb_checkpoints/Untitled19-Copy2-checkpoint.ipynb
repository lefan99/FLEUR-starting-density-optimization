# %%
from aiida_fleur.data.fleurinp import FleurinpData
from aiida import load_profile
from aiida.orm import Dict, load_node , load_code
from aiida.engine import submit, run
from aiida_fleur.calculation.fleurinputgen import FleurinputgenCalculation
from aiida.plugins import DataFactory, CalculationFactory
from aiida_fleur.calculation.fleur import FleurCalculation
from aiida_fleur.data.fleurinpmodifier import FleurinpModifier
from itertools import product
import numpy as np
import json
import matplotlib.pyplot as plt
import numpy as np
import random
from fleur_starting_density import oxides_charge1

load_profile()

# %%
calc = [ 147696 , 147697 , 147698 , 147699 , 147700 ]


inps = []

for number in calc:
    
    inps.append(load_node(number).outputs.fleurinpData)

# %%
inps
# Out:
# [<FleurinpData: uuid: 553876d3-4f30-4be4-85a4-2da20fddcf51 (pk: 147709)>,
#  <FleurinpData: uuid: 1d21c67a-93f6-4599-8f89-3a965dbf38cc (pk: 147715)>,
#  <FleurinpData: uuid: 8ac3f344-e9e2-4dbb-a60c-e613186137a5 (pk: 147714)>,
#  <FleurinpData: uuid: 02c45d1c-b35a-4ee8-ab39-3adaaee92f8c (pk: 147713)>,
#  <FleurinpData: uuid: 16c1c420-b142-4f3d-8e26-6c88451a0768 (pk: 147707)>]

# %%
results = [ ]

for inp in inps:
    
    results.append(oxides_charge1( inp))
# Out:
# started fleur calc with pk: 147730
# started fleur calc with pk: 147734
# started fleur calc with pk: 147738
# started fleur calc with pk: 147742
# started fleur calc with pk: 147746
# started fleur calc with pk: 147750
# started fleur calc with pk: 147754
# started fleur calc with pk: 147758
# started fleur calc with pk: 147762
# started fleur calc with pk: 147766
# started fleur calc with pk: 147770
# started fleur calc with pk: 147774
# started fleur calc with pk: 147778
# started fleur calc with pk: 147782
# started fleur calc with pk: 147786
# started fleur calc with pk: 147790
# started fleur calc with pk: 147794
# started fleur calc with pk: 147798
# started fleur calc with pk: 147802
# started fleur calc with pk: 147806
# started fleur calc with pk: 147813
# started fleur calc with pk: 147817
# started fleur calc with pk: 147821
# started fleur calc with pk: 147825
# started fleur calc with pk: 147829
# started fleur calc with pk: 147833
# started fleur calc with pk: 147837
# started fleur calc with pk: 147841
# started fleur calc with pk: 147845
# started fleur calc with pk: 147849
# started fleur calc with pk: 147854
# started fleur calc with pk: 147858
# started fleur calc with pk: 147862
# started fleur calc with pk: 147866
# started fleur calc with pk: 147870
# started fleur calc with pk: 147874
# started fleur calc with pk: 147878
# started fleur calc with pk: 147882
# started fleur calc with pk: 147886
# started fleur calc with pk: 147890
# started fleur calc with pk: 147897
# started fleur calc with pk: 147901
# started fleur calc with pk: 147905
# started fleur calc with pk: 147909
# started fleur calc with pk: 147913
# started fleur calc with pk: 147917
# started fleur calc with pk: 147921
# started fleur calc with pk: 147925
# started fleur calc with pk: 147929
# started fleur calc with pk: 147933
# started fleur calc with pk: 147937
# started fleur calc with pk: 147941
# started fleur calc with pk: 147945
# started fleur calc with pk: 147949
# started fleur calc with pk: 147953
# started fleur calc with pk: 147957
# started fleur calc with pk: 147961
# started fleur calc with pk: 147965
# started fleur calc with pk: 147969
# started fleur calc with pk: 147973
# started fleur calc with pk: 147980
# started fleur calc with pk: 147984
# started fleur calc with pk: 147988
# started fleur calc with pk: 147992
# started fleur calc with pk: 147996
# started fleur calc with pk: 148000
# started fleur calc with pk: 148004
# started fleur calc with pk: 148008
# started fleur calc with pk: 148012
# started fleur calc with pk: 148016
# started fleur calc with pk: 148020
# started fleur calc with pk: 148024
# started fleur calc with pk: 148028
# started fleur calc with pk: 148032
# started fleur calc with pk: 148036
# started fleur calc with pk: 148040
# started fleur calc with pk: 148055
# started fleur calc with pk: 148059
# started fleur calc with pk: 148063
# started fleur calc with pk: 148067
# started fleur calc with pk: 148085
# started fleur calc with pk: 148089
# started fleur calc with pk: 148093
# started fleur calc with pk: 148097
# started fleur calc with pk: 148111
# started fleur calc with pk: 148116
# started fleur calc with pk: 148120
# started fleur calc with pk: 148124
# started fleur calc with pk: 148133
# started fleur calc with pk: 148143
# started fleur calc with pk: 148147
# started fleur calc with pk: 148152
# started fleur calc with pk: 148159
# started fleur calc with pk: 148170
# started fleur calc with pk: 148174
# started fleur calc with pk: 148178
# started fleur calc with pk: 148183
# started fleur calc with pk: 148187
# started fleur calc with pk: 148191
# started fleur calc with pk: 148196

# %%
import pickle 


file = open('results_s_charge_transfer.pickle' , 'wb')
pickle.dump(results , file )

# %%
def plot(lis) :
    
    x = []
    y = []
    
    for species in lis[0].inputs.fleurinpdata.inp_dict['atomSpecies']:

        if species['name'] != 'Oxygen (O)':

            X_name = species['name']
    
    
    for node in lis:
        
        if node.is_finished_ok:
    
            y.append( node.outputs.output_parameters.get_dict()['density_convergence'] )
        
            x.append(2 * (node.inputs.fleurinpdata.inp_dict['atomSpecies'][1]['electronConfig']['stateOccupation'][0]['spinUp'] + node.inputs.fleurinpdata.inp_dict['atomSpecies'][1]['electronConfig']['stateOccupation'][1]['spinUp'] ) -4)

    
    plt.plot(x,y, 'x') 
    plt.xlabel('total charge transfer to Oxygen')
    plt.ylabel('distance after 1 iteration')
    plt.title(X_name)
    #plt.savefig('MgO_sc_loop.pdf')
    plt.show()

# %%
for i in results:
    
    plot(i)

# %%
for node in results[-1]:
    
    print(node.inputs.fleurinpdata.inp_dict['atomSpecies'][0]['electronConfig'], node.inputs.fleurinpdata.inp_dict['atomSpecies'][1]['electronConfig']['stateOccupation'])
# Out:
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 1.0, 'spinDown': 1.0}]} [{'state': '(2p1/2)', 'spinUp': 0.6666666667, 'spinDown': 0.6666666667}, {'state': '(2p3/2)', 'spinUp': 1.3333333333, 'spinDown': 1.3333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.95, 'spinDown': 0.95}]} [{'state': '(2p1/2)', 'spinUp': 0.6833333333, 'spinDown': 0.6833333333}, {'state': '(2p3/2)', 'spinUp': 1.3666666667, 'spinDown': 1.3666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.9, 'spinDown': 0.9}]} [{'state': '(2p1/2)', 'spinUp': 0.7, 'spinDown': 0.7}, {'state': '(2p3/2)', 'spinUp': 1.4, 'spinDown': 1.4}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.85, 'spinDown': 0.85}]} [{'state': '(2p1/2)', 'spinUp': 0.7166666667, 'spinDown': 0.7166666667}, {'state': '(2p3/2)', 'spinUp': 1.4333333333, 'spinDown': 1.4333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.8, 'spinDown': 0.8}]} [{'state': '(2p1/2)', 'spinUp': 0.7333333333, 'spinDown': 0.7333333333}, {'state': '(2p3/2)', 'spinUp': 1.4666666667, 'spinDown': 1.4666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.75, 'spinDown': 0.75}]} [{'state': '(2p1/2)', 'spinUp': 0.75, 'spinDown': 0.75}, {'state': '(2p3/2)', 'spinUp': 1.5, 'spinDown': 1.5}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.7, 'spinDown': 0.7}]} [{'state': '(2p1/2)', 'spinUp': 0.7666666667, 'spinDown': 0.7666666667}, {'state': '(2p3/2)', 'spinUp': 1.5333333333, 'spinDown': 1.5333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.65, 'spinDown': 0.65}]} [{'state': '(2p1/2)', 'spinUp': 0.7833333333, 'spinDown': 0.7833333333}, {'state': '(2p3/2)', 'spinUp': 1.5666666667, 'spinDown': 1.5666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.6, 'spinDown': 0.6}]} [{'state': '(2p1/2)', 'spinUp': 0.8, 'spinDown': 0.8}, {'state': '(2p3/2)', 'spinUp': 1.6, 'spinDown': 1.6}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.55, 'spinDown': 0.55}]} [{'state': '(2p1/2)', 'spinUp': 0.8166666667, 'spinDown': 0.8166666667}, {'state': '(2p3/2)', 'spinUp': 1.6333333333, 'spinDown': 1.6333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]} [{'state': '(2p1/2)', 'spinUp': 0.8333333333, 'spinDown': 0.8333333333}, {'state': '(2p3/2)', 'spinUp': 1.6666666667, 'spinDown': 1.6666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.45, 'spinDown': 0.45}]} [{'state': '(2p1/2)', 'spinUp': 0.85, 'spinDown': 0.85}, {'state': '(2p3/2)', 'spinUp': 1.7, 'spinDown': 1.7}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.4, 'spinDown': 0.4}]} [{'state': '(2p1/2)', 'spinUp': 0.8666666667, 'spinDown': 0.8666666667}, {'state': '(2p3/2)', 'spinUp': 1.7333333333, 'spinDown': 1.7333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.35, 'spinDown': 0.35}]} [{'state': '(2p1/2)', 'spinUp': 0.8833333333, 'spinDown': 0.8833333333}, {'state': '(2p3/2)', 'spinUp': 1.7666666667, 'spinDown': 1.7666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.3, 'spinDown': 0.3}]} [{'state': '(2p1/2)', 'spinUp': 0.9, 'spinDown': 0.9}, {'state': '(2p3/2)', 'spinUp': 1.8, 'spinDown': 1.8}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.25, 'spinDown': 0.25}]} [{'state': '(2p1/2)', 'spinUp': 0.9166666667, 'spinDown': 0.9166666667}, {'state': '(2p3/2)', 'spinUp': 1.8333333333, 'spinDown': 1.8333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.2, 'spinDown': 0.2}]} [{'state': '(2p1/2)', 'spinUp': 0.9333333333, 'spinDown': 0.9333333333}, {'state': '(2p3/2)', 'spinUp': 1.8666666667, 'spinDown': 1.8666666667}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.15, 'spinDown': 0.15}]} [{'state': '(2p1/2)', 'spinUp': 0.95, 'spinDown': 0.95}, {'state': '(2p3/2)', 'spinUp': 1.9, 'spinDown': 1.9}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.1, 'spinDown': 0.1}]} [{'state': '(2p1/2)', 'spinUp': 0.9666666667, 'spinDown': 0.9666666667}, {'state': '(2p3/2)', 'spinUp': 1.9333333333, 'spinDown': 1.9333333333}]
# {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)'], 'valenceConfig': ['(6s1/2)', '(6p1/2)', '(6p3/2)', '(7s1/2)'], 'stateOccupation': [{'state': '(7s1/2)', 'spinUp': 0.05, 'spinDown': 0.05}]} [{'state': '(2p1/2)', 'spinUp': 0.9833333333, 'spinDown': 0.9833333333}, {'state': '(2p3/2)', 'spinUp': 1.9666666667, 'spinDown': 1.9666666667}]
