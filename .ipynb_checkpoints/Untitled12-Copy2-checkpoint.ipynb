# %%
from aiida_fleur.data.fleurinp import FleurinpData
from aiida import load_profile
from aiida.orm import Dict, load_node , load_code , load_group
from aiida.engine import submit, run
from aiida_fleur.calculation.fleurinputgen import FleurinputgenCalculation
from aiida.plugins import DataFactory, CalculationFactory
from aiida_fleur.calculation.fleur import FleurCalculation
from aiida_fleur.data.fleurinpmodifier import FleurinpModifier
from itertools import product
import numpy as np
import json
import matplotlib.pyplot as plt
import numpy as np
import random
from fleur_starting_density import oxides_all


load_profile()

# %%
inp = load_node(153605)

# %%
# Out:
# uuid: 02c0040d-cf64-4057-8c1d-cbc3d702848d (pk: 154074) (aiida.calculations:fleur.inpgen)
# uuid: 98381d6d-64aa-4d56-8c91-bd395b8cc437 (pk: 154075) (aiida.calculations:fleur.inpgen)
# uuid: ef5ca77e-0c04-47ba-851f-5ba0d4627c5e (pk: 154076) (aiida.calculations:fleur.inpgen)
# uuid: 5c9b73dd-572f-4e5b-a56f-038ea66d5c37 (pk: 154077) (aiida.calculations:fleur.inpgen)
# uuid: 8ccfcc3a-0b5f-45a9-95fb-a93a42677d79 (pk: 154078) (aiida.calculations:fleur.inpgen)
# uuid: 98d6c470-00d4-495f-a853-ddf5bbcea25e (pk: 154079) (aiida.calculations:fleur.inpgen)
# uuid: 34c44bc1-371a-434f-a9eb-5f00ab1d09b1 (pk: 154080) (aiida.calculations:fleur.inpgen)
# uuid: 2cec4d32-5b7e-41c0-aeda-640fa76b2e1d (pk: 154081) (aiida.calculations:fleur.inpgen)
# uuid: 8ea8e6b3-8e86-4909-90e5-c2a2b259b038 (pk: 154082) (aiida.calculations:fleur.inpgen)
# uuid: 54e37ac7-eada-4fde-bb65-f0b1601fb423 (pk: 154083) (aiida.calculations:fleur.inpgen)
# uuid: 5e1298a1-0598-4610-bff2-4cc34f458a03 (pk: 154084) (aiida.calculations:fleur.inpgen)
# uuid: b480a503-a34a-436a-aba7-a591c245ea32 (pk: 154085) (aiida.calculations:fleur.inpgen)
# uuid: 082d1343-a7d6-461d-884c-3c99de81d300 (pk: 154086) (aiida.calculations:fleur.inpgen)
# uuid: 94d3a9f3-67e5-4ae0-a25e-c80d16ca8f6c (pk: 154087) (aiida.calculations:fleur.inpgen)
# uuid: 9309a040-a6f7-45c0-8deb-5988b292c500 (pk: 154088) (aiida.calculations:fleur.inpgen)
# uuid: 5476ca70-75ef-43c8-ac27-3ca2bfdffdfb (pk: 154089) (aiida.calculations:fleur.inpgen)
# uuid: 0b6e0e39-ec3e-41b2-b015-75541019b42c (pk: 154090) (aiida.calculations:fleur.inpgen)
# uuid: 3662b742-3935-404e-8722-c3cb0e60740c (pk: 154091) (aiida.calculations:fleur.inpgen)
# uuid: a7f21a3d-6863-4fcc-bc8a-fe0ba13442b1 (pk: 154092) (aiida.calculations:fleur.inpgen)
# uuid: 2cb7d807-0da0-4ab5-8bc2-a2a01091fe2a (pk: 154093) (aiida.calculations:fleur.inpgen)
# uuid: ce88fdf9-9eaa-4162-9024-eda61e16707b (pk: 154094) (aiida.calculations:fleur.inpgen)
# uuid: 7add506f-eac1-47e2-8466-1902e69f84a6 (pk: 154095) (aiida.calculations:fleur.inpgen)
# uuid: 896b76c1-1480-4ad3-ba78-2732bb1d63d5 (pk: 154096) (aiida.calculations:fleur.inpgen)
# uuid: 3cac8a3c-eb32-44e9-a748-30f29a8d4193 (pk: 154097) (aiida.calculations:fleur.inpgen)
# uuid: 79e0f410-221e-41d0-8567-20175b840942 (pk: 154098) (aiida.calculations:fleur.inpgen)
# uuid: a2ca1443-65af-46a6-b779-7b63c5c83859 (pk: 154099) (aiida.calculations:fleur.inpgen)
# uuid: 21678221-3f09-4972-9df7-3ebc2e99db2a (pk: 154100) (aiida.calculations:fleur.inpgen)
# uuid: 2ffe8344-9a33-4322-967d-ca6c4bfa554c (pk: 154101) (aiida.calculations:fleur.inpgen)
# uuid: 161ca90a-acf7-40fc-a8cd-5f1e9b1fdc2a (pk: 154102) (aiida.calculations:fleur.inpgen)

# %%
inps = []

for i in range(154102-154074):

    
    inps.append(load_node(i + 154074).outputs.fleurinpData)

# %%
len(inps)
# Out:
# 28

# %%
from aiida.orm import groups


group = load_group(label = 'first30')

# %%
len(group.nodes)
# Out:
# 20

# %%
for i in res_l:
    group.add_nodes(i)

# %%
inp[0].outputs.fleurinpData.inp_dict['atomSpecies']
# Out:
# [{'name': 'Chlorine (Cl)',
#   'element': 'Cl',
#   'mtSphere': {'radius': 2.4, 'gridPoints': 793, 'logIncrement': 0.015},
#   'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'},
#   'modInitDen': {'flipSpinPhi': 0.0,
#    'flipSpinScale': False,
#    'flipSpinTheta': 0.0},
#   'atomicNumber': 17,
#   'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8},
#   'electronConfig': {'coreConfig': ['(1s1/2)',
#     '(2s1/2)',
#     '(2p1/2)',
#     '(2p3/2)'],
#    'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'],
#    'stateOccupation': [{'state': '(3p1/2)',
#      'spinUp': 0.83333333,
#      'spinDown': 0.83333333},
#     {'state': '(3p3/2)', 'spinUp': 1.66666667, 'spinDown': 1.66666667}]},
#   'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}},
#  {'name': 'Oxygen (O)',
#   'element': 'O',
#   'mtSphere': {'radius': 1.73, 'gridPoints': 573, 'logIncrement': 0.019},
#   'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'},
#   'modInitDen': {'flipSpinPhi': 0.0,
#    'flipSpinScale': False,
#    'flipSpinTheta': 0.0},
#   'atomicNumber': 8,
#   'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4},
#   'electronConfig': {'coreConfig': ['(1s1/2)'],
#    'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'],
#    'stateOccupation': [{'state': '(2p1/2)',
#      'spinUp': 0.66666667,
#      'spinDown': 0.66666667},
#     {'state': '(2p3/2)', 'spinUp': 1.33333333, 'spinDown': 1.33333333}]},
#   'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]

# %%
res_l = []

for i in inps:
    
    try:
    
        print(i.inp_dict['atomSpecies'][0])
        res_l.append(oxides_all(i, gridsize = 10))
        
    except:
        
        pass
# Out:
# {'name': 'Chlorine (Cl)', 'element': 'Cl', 'mtSphere': {'radius': 2.4, 'gridPoints': 793, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 17, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'], 'stateOccupation': [{'state': '(3p1/2)', 'spinUp': 0.83333333, 'spinDown': 0.83333333}, {'state': '(3p3/2)', 'spinUp': 1.66666667, 'spinDown': 1.66666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3p1/2)', '(3p3/2)'] 2
# [0.333333332, 0.666666668] ['(3p1/2)', '(3p3/2)']
# 2.5 2
# [{'state': '(3p1/2)', 'spinup': 0.83333333, 'spindown': 0.83333333}, {'state': '(3p3/2)', 'spinup': 1.66666667, 'spindown': 1.66666667}]
# started fleur calc with pk: 154789
# 2.45 2.025
# [{'state': '(3p1/2)', 'spinup': 0.8166666634, 'spindown': 0.8166666634}, {'state': '(3p3/2)', 'spinup': 1.6333333366, 'spindown': 1.6333333366}]
# started fleur calc with pk: 154793
# 2.4000000000000004 2.05
# [{'state': '(3p1/2)', 'spinup': 0.7999999968000001, 'spindown': 0.7999999968000001}, {'state': '(3p3/2)', 'spinup': 1.6000000032000001, 'spindown': 1.6000000032000001}]
# started fleur calc with pk: 154797
# 2.3500000000000005 2.0749999999999997
# [{'state': '(3p1/2)', 'spinup': 0.7833333302000002, 'spindown': 0.7833333302000002}, {'state': '(3p3/2)', 'spinup': 1.5666666698000002, 'spindown': 1.5666666698000002}]
# started fleur calc with pk: 154801
# 2.3000000000000007 2.0999999999999996
# [{'state': '(3p1/2)', 'spinup': 0.7666666636000002, 'spindown': 0.7666666636000002}, {'state': '(3p3/2)', 'spinup': 1.5333333364000004, 'spindown': 1.5333333364000004}]
# started fleur calc with pk: 154805
# 2.250000000000001 2.1249999999999996
# [{'state': '(3p1/2)', 'spinup': 0.7499999970000003, 'spindown': 0.7499999970000003}, {'state': '(3p3/2)', 'spinup': 1.5000000030000005, 'spindown': 1.5000000030000005}]
# started fleur calc with pk: 154809
# 2.200000000000001 2.1499999999999995
# [{'state': '(3p1/2)', 'spinup': 0.7333333304000003, 'spindown': 0.7333333304000003}, {'state': '(3p3/2)', 'spinup': 1.4666666696000006, 'spindown': 1.4666666696000006}]
# started fleur calc with pk: 154813
# 2.1500000000000012 2.1749999999999994
# [{'state': '(3p1/2)', 'spinup': 0.7166666638000003, 'spindown': 0.7166666638000003}, {'state': '(3p3/2)', 'spinup': 1.4333333362000007, 'spindown': 1.4333333362000007}]
# started fleur calc with pk: 154817
# 2.1000000000000014 2.1999999999999993
# [{'state': '(3p1/2)', 'spinup': 0.6999999972000004, 'spindown': 0.6999999972000004}, {'state': '(3p3/2)', 'spinup': 1.4000000028000008, 'spindown': 1.4000000028000008}]
# started fleur calc with pk: 154821
# 2.0500000000000016 2.224999999999999
# [{'state': '(3p1/2)', 'spinup': 0.6833333306000005, 'spindown': 0.6833333306000005}, {'state': '(3p3/2)', 'spinup': 1.366666669400001, 'spindown': 1.366666669400001}]
# started fleur calc with pk: 154825
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Scandium (Sc)', 'element': 'Sc', 'mtSphere': {'radius': 2.59, 'gridPoints': 857, 'logIncrement': 0.014}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 21, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 0.2, 'spinDown': 0.2}, {'state': '(3d5/2)', 'spinUp': 0.3, 'spinDown': 0.3}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# ['(3d3/2)', '(3d5/2)'] 2
# [0.4, 0.6] ['(3d3/2)', '(3d5/2)']
# 0.5 2
# [{'state': '(3d3/2)', 'spinup': 0.2, 'spindown': 0.2}, {'state': '(3d5/2)', 'spinup': 0.3, 'spindown': 0.3}]
# started fleur calc with pk: 154832
# 0.45 2.025
# [{'state': '(3d3/2)', 'spinup': 0.18000000000000002, 'spindown': 0.18000000000000002}, {'state': '(3d5/2)', 'spinup': 0.27, 'spindown': 0.27}]
# started fleur calc with pk: 154836
# 0.4 2.05
# [{'state': '(3d3/2)', 'spinup': 0.16000000000000003, 'spindown': 0.16000000000000003}, {'state': '(3d5/2)', 'spinup': 0.24, 'spindown': 0.24}]
# started fleur calc with pk: 154840
# 0.35000000000000003 2.0749999999999997
# [{'state': '(3d3/2)', 'spinup': 0.14, 'spindown': 0.14}, {'state': '(3d5/2)', 'spinup': 0.21000000000000002, 'spindown': 0.21000000000000002}]
# started fleur calc with pk: 154844
# 0.30000000000000004 2.0999999999999996
# [{'state': '(3d3/2)', 'spinup': 0.12000000000000002, 'spindown': 0.12000000000000002}, {'state': '(3d5/2)', 'spinup': 0.18000000000000002, 'spindown': 0.18000000000000002}]
# started fleur calc with pk: 154848
# 0.25000000000000006 2.1249999999999996
# [{'state': '(3d3/2)', 'spinup': 0.10000000000000003, 'spindown': 0.10000000000000003}, {'state': '(3d5/2)', 'spinup': 0.15000000000000002, 'spindown': 0.15000000000000002}]
# started fleur calc with pk: 154852
# 0.20000000000000007 2.1499999999999995
# [{'state': '(3d3/2)', 'spinup': 0.08000000000000003, 'spindown': 0.08000000000000003}, {'state': '(3d5/2)', 'spinup': 0.12000000000000004, 'spindown': 0.12000000000000004}]
# started fleur calc with pk: 154856
# 0.15000000000000008 2.1749999999999994
# [{'state': '(3d3/2)', 'spinup': 0.06000000000000003, 'spindown': 0.06000000000000003}, {'state': '(3d5/2)', 'spinup': 0.09000000000000004, 'spindown': 0.09000000000000004}]
# started fleur calc with pk: 154860
# 0.10000000000000007 2.1999999999999993
# [{'state': '(3d3/2)', 'spinup': 0.040000000000000036, 'spindown': 0.040000000000000036}, {'state': '(3d5/2)', 'spinup': 0.06000000000000004, 'spindown': 0.06000000000000004}]
# started fleur calc with pk: 154864
# 0.05000000000000007 2.224999999999999
# [{'state': '(3d3/2)', 'spinup': 0.02000000000000003, 'spindown': 0.02000000000000003}, {'state': '(3d5/2)', 'spinup': 0.03000000000000004, 'spindown': 0.03000000000000004}]
# started fleur calc with pk: 154868
# {'lo': [{'l': 0, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Sodium (Na)', 'element': 'Na', 'mtSphere': {'radius': 2.69, 'gridPoints': 889, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 11, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)'], 'stateOccupation': [{'state': '(3s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3s1/2)'] 1
# [1.0] ['(3s1/2)']
# 0.5 2
# [{'state': '(3s1/2)', 'spinup': 0.5, 'spindown': 0.5}]
# started fleur calc with pk: 154875
# 0.45 2.025
# [{'state': '(3s1/2)', 'spinup': 0.45, 'spindown': 0.45}]
# started fleur calc with pk: 154879
# 0.4 2.05
# [{'state': '(3s1/2)', 'spinup': 0.4, 'spindown': 0.4}]
# started fleur calc with pk: 154883
# 0.35000000000000003 2.0749999999999997
# [{'state': '(3s1/2)', 'spinup': 0.35000000000000003, 'spindown': 0.35000000000000003}]
# started fleur calc with pk: 154887
# 0.30000000000000004 2.0999999999999996
# [{'state': '(3s1/2)', 'spinup': 0.30000000000000004, 'spindown': 0.30000000000000004}]
# started fleur calc with pk: 154891
# 0.25000000000000006 2.1249999999999996
# [{'state': '(3s1/2)', 'spinup': 0.25000000000000006, 'spindown': 0.25000000000000006}]
# started fleur calc with pk: 154895
# 0.20000000000000007 2.1499999999999995
# [{'state': '(3s1/2)', 'spinup': 0.20000000000000007, 'spindown': 0.20000000000000007}]
# started fleur calc with pk: 154899
# 0.15000000000000008 2.1749999999999994
# [{'state': '(3s1/2)', 'spinup': 0.15000000000000008, 'spindown': 0.15000000000000008}]
# started fleur calc with pk: 154903
# 0.10000000000000007 2.1999999999999993
# [{'state': '(3s1/2)', 'spinup': 0.10000000000000007, 'spindown': 0.10000000000000007}]
# started fleur calc with pk: 154907
# 0.05000000000000007 2.224999999999999
# [{'state': '(3s1/2)', 'spinup': 0.05000000000000007, 'spindown': 0.05000000000000007}]
# started fleur calc with pk: 154911
# {'name': 'Neon (Ne)', 'element': 'Ne', 'mtSphere': {'radius': 2.74, 'gridPoints': 905, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 10, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# [0.3333333333333333, 0.6666666666666666] ['(2p3/2)', '(2p1/2)']
# 3 2
# [{'state': '(2p3/2)', 'spinup': 1.0, 'spindown': 1.0}, {'state': '(2p1/2)', 'spinup': 2.0, 'spindown': 2.0}]
# started fleur calc with pk: 154918
# 2.95 2.025
# [{'state': '(2p3/2)', 'spinup': 0.9833333333333334, 'spindown': 0.9833333333333334}, {'state': '(2p1/2)', 'spinup': 1.9666666666666668, 'spindown': 1.9666666666666668}]
# started fleur calc with pk: 154922
# 2.9000000000000004 2.05
# [{'state': '(2p3/2)', 'spinup': 0.9666666666666668, 'spindown': 0.9666666666666668}, {'state': '(2p1/2)', 'spinup': 1.9333333333333336, 'spindown': 1.9333333333333336}]
# started fleur calc with pk: 154926
# 2.8500000000000005 2.0749999999999997
# [{'state': '(2p3/2)', 'spinup': 0.9500000000000002, 'spindown': 0.9500000000000002}, {'state': '(2p1/2)', 'spinup': 1.9000000000000004, 'spindown': 1.9000000000000004}]
# started fleur calc with pk: 154930
# 2.8000000000000007 2.0999999999999996
# [{'state': '(2p3/2)', 'spinup': 0.9333333333333336, 'spindown': 0.9333333333333336}, {'state': '(2p1/2)', 'spinup': 1.8666666666666671, 'spindown': 1.8666666666666671}]
# started fleur calc with pk: 154934
# 2.750000000000001 2.1249999999999996
# [{'state': '(2p3/2)', 'spinup': 0.916666666666667, 'spindown': 0.916666666666667}, {'state': '(2p1/2)', 'spinup': 1.833333333333334, 'spindown': 1.833333333333334}]
# started fleur calc with pk: 154938
# 2.700000000000001 2.1499999999999995
# [{'state': '(2p3/2)', 'spinup': 0.9000000000000004, 'spindown': 0.9000000000000004}, {'state': '(2p1/2)', 'spinup': 1.8000000000000007, 'spindown': 1.8000000000000007}]
# started fleur calc with pk: 154942
# 2.6500000000000012 2.1749999999999994
# [{'state': '(2p3/2)', 'spinup': 0.8833333333333337, 'spindown': 0.8833333333333337}, {'state': '(2p1/2)', 'spinup': 1.7666666666666675, 'spindown': 1.7666666666666675}]
# started fleur calc with pk: 154946
# 2.6000000000000014 2.1999999999999993
# [{'state': '(2p3/2)', 'spinup': 0.8666666666666671, 'spindown': 0.8666666666666671}, {'state': '(2p1/2)', 'spinup': 1.7333333333333343, 'spindown': 1.7333333333333343}]
# started fleur calc with pk: 154950
# 2.5500000000000016 2.224999999999999
# [{'state': '(2p3/2)', 'spinup': 0.8500000000000005, 'spindown': 0.8500000000000005}, {'state': '(2p1/2)', 'spinup': 1.700000000000001, 'spindown': 1.700000000000001}]
# started fleur calc with pk: 154954
# {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.9, 'gridPoints': 629, 'logIncrement': 0.017}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.66666667, 'spinDown': 0.66666667}, {'state': '(2p3/2)', 'spinUp': 1.33333333, 'spinDown': 1.33333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# {'name': 'Boron (B)', 'element': 'B', 'mtSphere': {'radius': 1.73, 'gridPoints': 573, 'logIncrement': 0.018}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 5, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.16666667, 'spinDown': 0.16666667}, {'state': '(2p3/2)', 'spinUp': 0.33333333, 'spinDown': 0.33333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# ['(2p1/2)', '(2p3/2)'] 2
# [0.33333334, 0.66666666] ['(2p1/2)', '(2p3/2)']
# 0.5 2
# [{'state': '(2p1/2)', 'spinup': 0.16666667, 'spindown': 0.16666667}, {'state': '(2p3/2)', 'spinup': 0.33333333, 'spindown': 0.33333333}]
# started fleur calc with pk: 154964
# 0.45 2.025
# [{'state': '(2p1/2)', 'spinup': 0.150000003, 'spindown': 0.150000003}, {'state': '(2p3/2)', 'spinup': 0.299999997, 'spindown': 0.299999997}]
# started fleur calc with pk: 154968
# 0.4 2.05
# [{'state': '(2p1/2)', 'spinup': 0.133333336, 'spindown': 0.133333336}, {'state': '(2p3/2)', 'spinup': 0.266666664, 'spindown': 0.266666664}]
# started fleur calc with pk: 154972
# 0.35000000000000003 2.0749999999999997
# [{'state': '(2p1/2)', 'spinup': 0.116666669, 'spindown': 0.116666669}, {'state': '(2p3/2)', 'spinup': 0.233333331, 'spindown': 0.233333331}]
# started fleur calc with pk: 154976
# 0.30000000000000004 2.0999999999999996
# [{'state': '(2p1/2)', 'spinup': 0.100000002, 'spindown': 0.100000002}, {'state': '(2p3/2)', 'spinup': 0.199999998, 'spindown': 0.199999998}]
# started fleur calc with pk: 154980
# 0.25000000000000006 2.1249999999999996
# [{'state': '(2p1/2)', 'spinup': 0.08333333500000001, 'spindown': 0.08333333500000001}, {'state': '(2p3/2)', 'spinup': 0.16666666500000002, 'spindown': 0.16666666500000002}]
# started fleur calc with pk: 154984
# 0.20000000000000007 2.1499999999999995
# [{'state': '(2p1/2)', 'spinup': 0.06666666800000001, 'spindown': 0.06666666800000001}, {'state': '(2p3/2)', 'spinup': 0.13333333200000003, 'spindown': 0.13333333200000003}]
# started fleur calc with pk: 154988
# 0.15000000000000008 2.1749999999999994
# [{'state': '(2p1/2)', 'spinup': 0.05000000100000002, 'spindown': 0.05000000100000002}, {'state': '(2p3/2)', 'spinup': 0.09999999900000005, 'spindown': 0.09999999900000005}]
# started fleur calc with pk: 154992
# 0.10000000000000007 2.1999999999999993
# [{'state': '(2p1/2)', 'spinup': 0.03333333400000002, 'spindown': 0.03333333400000002}, {'state': '(2p3/2)', 'spinup': 0.06666666600000004, 'spindown': 0.06666666600000004}]
# started fleur calc with pk: 154996
# 0.05000000000000007 2.224999999999999
# [{'state': '(2p1/2)', 'spinup': 0.016666667000000024, 'spindown': 0.016666667000000024}, {'state': '(2p3/2)', 'spinup': 0.03333333300000005, 'spindown': 0.03333333300000005}]
# started fleur calc with pk: 155000
# {'lo': [{'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Nickel (Ni)', 'element': 'Ni', 'mtSphere': {'radius': 2.4, 'gridPoints': 793, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 28, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)'], 'valenceConfig': ['(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 1.6, 'spinDown': 1.6}, {'state': '(3d5/2)', 'spinUp': 2.95, 'spinDown': 1.85}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# {'name': 'Beryllium (Be)', 'element': 'Be', 'mtSphere': {'radius': 2.27, 'gridPoints': 751, 'logIncrement': 0.014}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 4, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# [1] ['(2s1/2)']
# 1 2
# [{'state': '(2s1/2)', 'spinup': 1, 'spindown': 1}]
# started fleur calc with pk: 155007
# 0.95 2.025
# [{'state': '(2s1/2)', 'spinup': 0.95, 'spindown': 0.95}]
# started fleur calc with pk: 155011
# 0.8999999999999999 2.05
# [{'state': '(2s1/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155015
# 0.8499999999999999 2.0749999999999997
# [{'state': '(2s1/2)', 'spinup': 0.8499999999999999, 'spindown': 0.8499999999999999}]
# started fleur calc with pk: 155019
# 0.7999999999999998 2.0999999999999996
# [{'state': '(2s1/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155023
# 0.7499999999999998 2.1249999999999996
# [{'state': '(2s1/2)', 'spinup': 0.7499999999999998, 'spindown': 0.7499999999999998}]
# started fleur calc with pk: 155027
# 0.6999999999999997 2.1499999999999995
# [{'state': '(2s1/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155032
# 0.6499999999999997 2.1749999999999994
# [{'state': '(2s1/2)', 'spinup': 0.6499999999999997, 'spindown': 0.6499999999999997}]
# started fleur calc with pk: 155037
# 0.5999999999999996 2.1999999999999993
# [{'state': '(2s1/2)', 'spinup': 0.5999999999999996, 'spindown': 0.5999999999999996}]
# started fleur calc with pk: 155042
# 0.5499999999999996 2.224999999999999
# [{'state': '(2s1/2)', 'spinup': 0.5499999999999996, 'spindown': 0.5499999999999996}]
# started fleur calc with pk: 155047
# {'name': 'Helium (He)', 'element': 'He', 'mtSphere': {'radius': 2.36, 'gridPoints': 781, 'logIncrement': 0.012}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 2, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': {}, 'valenceConfig': ['(1s1/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 1}}
# [1] ['(1s1/2)']
# 1 2
# [{'state': '(1s1/2)', 'spinup': 1, 'spindown': 1}]
# started fleur calc with pk: 155055
# 0.95 2.025
# [{'state': '(1s1/2)', 'spinup': 0.95, 'spindown': 0.95}]
# started fleur calc with pk: 155061
# 0.8999999999999999 2.05
# [{'state': '(1s1/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155066
# 0.8499999999999999 2.0749999999999997
# [{'state': '(1s1/2)', 'spinup': 0.8499999999999999, 'spindown': 0.8499999999999999}]
# started fleur calc with pk: 155072
# 0.7999999999999998 2.0999999999999996
# [{'state': '(1s1/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155077
# 0.7499999999999998 2.1249999999999996
# [{'state': '(1s1/2)', 'spinup': 0.7499999999999998, 'spindown': 0.7499999999999998}]
# started fleur calc with pk: 155082
# 0.6999999999999997 2.1499999999999995
# [{'state': '(1s1/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155090
# 0.6499999999999997 2.1749999999999994
# [{'state': '(1s1/2)', 'spinup': 0.6499999999999997, 'spindown': 0.6499999999999997}]
# started fleur calc with pk: 155094
# 0.5999999999999996 2.1999999999999993
# [{'state': '(1s1/2)', 'spinup': 0.5999999999999996, 'spindown': 0.5999999999999996}]
# started fleur calc with pk: 155099
# 0.5499999999999996 2.224999999999999
# [{'state': '(1s1/2)', 'spinup': 0.5499999999999996, 'spindown': 0.5499999999999996}]
# started fleur calc with pk: 155103
# {'name': 'Argon (Ar)', 'element': 'Ar', 'mtSphere': {'radius': 2.8, 'gridPoints': 925, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 18, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# [0.3333333333333333, 0.6666666666666666] ['(3p3/2)', '(3p1/2)']
# 3 2
# [{'state': '(3p3/2)', 'spinup': 1.0, 'spindown': 1.0}, {'state': '(3p1/2)', 'spinup': 2.0, 'spindown': 2.0}]
# started fleur calc with pk: 155114
# 2.95 2.025
# [{'state': '(3p3/2)', 'spinup': 0.9833333333333334, 'spindown': 0.9833333333333334}, {'state': '(3p1/2)', 'spinup': 1.9666666666666668, 'spindown': 1.9666666666666668}]
# started fleur calc with pk: 155118
# 2.9000000000000004 2.05
# [{'state': '(3p3/2)', 'spinup': 0.9666666666666668, 'spindown': 0.9666666666666668}, {'state': '(3p1/2)', 'spinup': 1.9333333333333336, 'spindown': 1.9333333333333336}]
# started fleur calc with pk: 155124
# 2.8500000000000005 2.0749999999999997
# [{'state': '(3p3/2)', 'spinup': 0.9500000000000002, 'spindown': 0.9500000000000002}, {'state': '(3p1/2)', 'spinup': 1.9000000000000004, 'spindown': 1.9000000000000004}]
# started fleur calc with pk: 155129
# 2.8000000000000007 2.0999999999999996
# [{'state': '(3p3/2)', 'spinup': 0.9333333333333336, 'spindown': 0.9333333333333336}, {'state': '(3p1/2)', 'spinup': 1.8666666666666671, 'spindown': 1.8666666666666671}]
# started fleur calc with pk: 155137
# 2.750000000000001 2.1249999999999996
# [{'state': '(3p3/2)', 'spinup': 0.916666666666667, 'spindown': 0.916666666666667}, {'state': '(3p1/2)', 'spinup': 1.833333333333334, 'spindown': 1.833333333333334}]
# started fleur calc with pk: 155143
# 2.700000000000001 2.1499999999999995
# [{'state': '(3p3/2)', 'spinup': 0.9000000000000004, 'spindown': 0.9000000000000004}, {'state': '(3p1/2)', 'spinup': 1.8000000000000007, 'spindown': 1.8000000000000007}]
# started fleur calc with pk: 155147
# 2.6500000000000012 2.1749999999999994
# [{'state': '(3p3/2)', 'spinup': 0.8833333333333337, 'spindown': 0.8833333333333337}, {'state': '(3p1/2)', 'spinup': 1.7666666666666675, 'spindown': 1.7666666666666675}]
# started fleur calc with pk: 155155
# 2.6000000000000014 2.1999999999999993
# [{'state': '(3p3/2)', 'spinup': 0.8666666666666671, 'spindown': 0.8666666666666671}, {'state': '(3p1/2)', 'spinup': 1.7333333333333343, 'spindown': 1.7333333333333343}]
# started fleur calc with pk: 155163
# 2.5500000000000016 2.224999999999999
# [{'state': '(3p3/2)', 'spinup': 0.8500000000000005, 'spindown': 0.8500000000000005}, {'state': '(3p1/2)', 'spinup': 1.700000000000001, 'spindown': 1.700000000000001}]
# started fleur calc with pk: 155169
# {'name': 'Silicon (Si)', 'element': 'Si', 'mtSphere': {'radius': 2.34, 'gridPoints': 773, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 14, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'], 'stateOccupation': [{'state': '(3p1/2)', 'spinUp': 0.33333333, 'spinDown': 0.33333333}, {'state': '(3p3/2)', 'spinUp': 0.66666667, 'spinDown': 0.66666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3p1/2)', '(3p3/2)'] 2
# [0.33333333, 0.66666667] ['(3p1/2)', '(3p3/2)']
# 1.0 2
# [{'state': '(3p1/2)', 'spinup': 0.33333333, 'spindown': 0.33333333}, {'state': '(3p3/2)', 'spinup': 0.66666667, 'spindown': 0.66666667}]
# started fleur calc with pk: 155178
# 0.95 2.025
# [{'state': '(3p1/2)', 'spinup': 0.31666666349999995, 'spindown': 0.31666666349999995}, {'state': '(3p3/2)', 'spinup': 0.6333333365, 'spindown': 0.6333333365}]
# started fleur calc with pk: 155186
# 0.8999999999999999 2.05
# [{'state': '(3p1/2)', 'spinup': 0.29999999699999996, 'spindown': 0.29999999699999996}, {'state': '(3p3/2)', 'spinup': 0.600000003, 'spindown': 0.600000003}]
# started fleur calc with pk: 155193
# 0.8499999999999999 2.0749999999999997
# [{'state': '(3p1/2)', 'spinup': 0.2833333304999999, 'spindown': 0.2833333304999999}, {'state': '(3p3/2)', 'spinup': 0.5666666694999999, 'spindown': 0.5666666694999999}]
# started fleur calc with pk: 155198
# 0.7999999999999998 2.0999999999999996
# [{'state': '(3p1/2)', 'spinup': 0.26666666399999994, 'spindown': 0.26666666399999994}, {'state': '(3p3/2)', 'spinup': 0.5333333359999999, 'spindown': 0.5333333359999999}]
# started fleur calc with pk: 155205
# 0.7499999999999998 2.1249999999999996
# [{'state': '(3p1/2)', 'spinup': 0.2499999974999999, 'spindown': 0.2499999974999999}, {'state': '(3p3/2)', 'spinup': 0.5000000024999999, 'spindown': 0.5000000024999999}]
# started fleur calc with pk: 155212
# 0.6999999999999997 2.1499999999999995
# [{'state': '(3p1/2)', 'spinup': 0.2333333309999999, 'spindown': 0.2333333309999999}, {'state': '(3p3/2)', 'spinup': 0.4666666689999998, 'spindown': 0.4666666689999998}]
# started fleur calc with pk: 155218
# 0.6499999999999997 2.1749999999999994
# [{'state': '(3p1/2)', 'spinup': 0.21666666449999988, 'spindown': 0.21666666449999988}, {'state': '(3p3/2)', 'spinup': 0.4333333354999998, 'spindown': 0.4333333354999998}]
# started fleur calc with pk: 155224
# 0.5999999999999996 2.1999999999999993
# [{'state': '(3p1/2)', 'spinup': 0.19999999799999987, 'spindown': 0.19999999799999987}, {'state': '(3p3/2)', 'spinup': 0.4000000019999998, 'spindown': 0.4000000019999998}]
# started fleur calc with pk: 155228
# 0.5499999999999996 2.224999999999999
# [{'state': '(3p1/2)', 'spinup': 0.18333333149999986, 'spindown': 0.18333333149999986}, {'state': '(3p3/2)', 'spinup': 0.36666666849999974, 'spindown': 0.36666666849999974}]
# started fleur calc with pk: 155232
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Titanium (Ti)', 'element': 'Ti', 'mtSphere': {'radius': 2.46, 'gridPoints': 813, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 22, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 0.4, 'spinDown': 0.4}, {'state': '(3d5/2)', 'spinUp': 0.6, 'spinDown': 0.6}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# ['(3d3/2)', '(3d5/2)'] 2
# [0.4, 0.6] ['(3d3/2)', '(3d5/2)']
# 1.0 2
# [{'state': '(3d3/2)', 'spinup': 0.4, 'spindown': 0.4}, {'state': '(3d5/2)', 'spinup': 0.6, 'spindown': 0.6}]
# started fleur calc with pk: 155239
# 0.95 2.025
# [{'state': '(3d3/2)', 'spinup': 0.38, 'spindown': 0.38}, {'state': '(3d5/2)', 'spinup': 0.57, 'spindown': 0.57}]
# started fleur calc with pk: 155243
# 0.8999999999999999 2.05
# [{'state': '(3d3/2)', 'spinup': 0.36, 'spindown': 0.36}, {'state': '(3d5/2)', 'spinup': 0.5399999999999999, 'spindown': 0.5399999999999999}]
# started fleur calc with pk: 155247
# 0.8499999999999999 2.0749999999999997
# [{'state': '(3d3/2)', 'spinup': 0.33999999999999997, 'spindown': 0.33999999999999997}, {'state': '(3d5/2)', 'spinup': 0.5099999999999999, 'spindown': 0.5099999999999999}]
# started fleur calc with pk: 155251
# 0.7999999999999998 2.0999999999999996
# [{'state': '(3d3/2)', 'spinup': 0.31999999999999995, 'spindown': 0.31999999999999995}, {'state': '(3d5/2)', 'spinup': 0.47999999999999987, 'spindown': 0.47999999999999987}]
# started fleur calc with pk: 155255
# 0.7499999999999998 2.1249999999999996
# [{'state': '(3d3/2)', 'spinup': 0.29999999999999993, 'spindown': 0.29999999999999993}, {'state': '(3d5/2)', 'spinup': 0.44999999999999984, 'spindown': 0.44999999999999984}]
# started fleur calc with pk: 155259
# 0.6999999999999997 2.1499999999999995
# [{'state': '(3d3/2)', 'spinup': 0.2799999999999999, 'spindown': 0.2799999999999999}, {'state': '(3d5/2)', 'spinup': 0.4199999999999998, 'spindown': 0.4199999999999998}]
# started fleur calc with pk: 155263
# 0.6499999999999997 2.1749999999999994
# [{'state': '(3d3/2)', 'spinup': 0.2599999999999999, 'spindown': 0.2599999999999999}, {'state': '(3d5/2)', 'spinup': 0.3899999999999998, 'spindown': 0.3899999999999998}]
# started fleur calc with pk: 155267
# 0.5999999999999996 2.1999999999999993
# [{'state': '(3d3/2)', 'spinup': 0.23999999999999988, 'spindown': 0.23999999999999988}, {'state': '(3d5/2)', 'spinup': 0.35999999999999976, 'spindown': 0.35999999999999976}]
# started fleur calc with pk: 155271
# 0.5499999999999996 2.224999999999999
# [{'state': '(3d3/2)', 'spinup': 0.21999999999999986, 'spindown': 0.21999999999999986}, {'state': '(3d5/2)', 'spinup': 0.32999999999999974, 'spindown': 0.32999999999999974}]
# started fleur calc with pk: 155275
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Iron (Fe)', 'element': 'Fe', 'mtSphere': {'radius': 2.34, 'gridPoints': 773, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 26, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 1.2, 'spinDown': 1.2}, {'state': '(3d5/2)', 'spinUp': 2.9, 'spinDown': 0.7}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Chromium (Cr)', 'element': 'Cr', 'mtSphere': {'radius': 2.38, 'gridPoints': 787, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 24, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(4s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}, {'state': '(3d3/2)', 'spinUp': 1.0, 'spinDown': 1.0}, {'state': '(3d5/2)', 'spinUp': 2.0, 'spinDown': 1.0}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# {'name': 'Hydrogen (H)', 'element': 'H', 'mtSphere': {'radius': 1.47, 'gridPoints': 487, 'logIncrement': 0.017}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 1, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': {}, 'valenceConfig': ['(1s1/2)'], 'stateOccupation': [{'state': '(1s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 1}}
# ['(1s1/2)'] 1
# [1.0] ['(1s1/2)']
# 0.5 2
# [{'state': '(1s1/2)', 'spinup': 0.5, 'spindown': 0.5}]
# started fleur calc with pk: 155282
# 0.45 2.025
# [{'state': '(1s1/2)', 'spinup': 0.45, 'spindown': 0.45}]
# started fleur calc with pk: 155286
# 0.4 2.05
# [{'state': '(1s1/2)', 'spinup': 0.4, 'spindown': 0.4}]
# started fleur calc with pk: 155290
# 0.35000000000000003 2.0749999999999997
# [{'state': '(1s1/2)', 'spinup': 0.35000000000000003, 'spindown': 0.35000000000000003}]
# started fleur calc with pk: 155294
# 0.30000000000000004 2.0999999999999996
# [{'state': '(1s1/2)', 'spinup': 0.30000000000000004, 'spindown': 0.30000000000000004}]
# started fleur calc with pk: 155298
# 0.25000000000000006 2.1249999999999996
# [{'state': '(1s1/2)', 'spinup': 0.25000000000000006, 'spindown': 0.25000000000000006}]
# started fleur calc with pk: 155302
# 0.20000000000000007 2.1499999999999995
# [{'state': '(1s1/2)', 'spinup': 0.20000000000000007, 'spindown': 0.20000000000000007}]
# started fleur calc with pk: 155306
# 0.15000000000000008 2.1749999999999994
# [{'state': '(1s1/2)', 'spinup': 0.15000000000000008, 'spindown': 0.15000000000000008}]
# started fleur calc with pk: 155310
# 0.10000000000000007 2.1999999999999993
# [{'state': '(1s1/2)', 'spinup': 0.10000000000000007, 'spindown': 0.10000000000000007}]
# started fleur calc with pk: 155314
# 0.05000000000000007 2.224999999999999
# [{'state': '(1s1/2)', 'spinup': 0.05000000000000007, 'spindown': 0.05000000000000007}]
# started fleur calc with pk: 155318
# {'name': 'Copper (Cu)', 'element': 'Cu', 'mtSphere': {'radius': 2.46, 'gridPoints': 813, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 29, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)'], 'valenceConfig': ['(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(4s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# ['(4s1/2)'] 1
# [1.0] ['(4s1/2)']
# 0.5 2
# [{'state': '(4s1/2)', 'spinup': 0.5, 'spindown': 0.5}]
# started fleur calc with pk: 155325
# 0.45 2.025
# [{'state': '(4s1/2)', 'spinup': 0.45, 'spindown': 0.45}]
# started fleur calc with pk: 155329
# 0.4 2.05
# [{'state': '(4s1/2)', 'spinup': 0.4, 'spindown': 0.4}]
# started fleur calc with pk: 155333
# 0.35000000000000003 2.0749999999999997
# [{'state': '(4s1/2)', 'spinup': 0.35000000000000003, 'spindown': 0.35000000000000003}]
# started fleur calc with pk: 155337
# 0.30000000000000004 2.0999999999999996
# [{'state': '(4s1/2)', 'spinup': 0.30000000000000004, 'spindown': 0.30000000000000004}]
# started fleur calc with pk: 155341
# 0.25000000000000006 2.1249999999999996
# [{'state': '(4s1/2)', 'spinup': 0.25000000000000006, 'spindown': 0.25000000000000006}]
# started fleur calc with pk: 155345
# 0.20000000000000007 2.1499999999999995
# [{'state': '(4s1/2)', 'spinup': 0.20000000000000007, 'spindown': 0.20000000000000007}]
# started fleur calc with pk: 155349
# 0.15000000000000008 2.1749999999999994
# [{'state': '(4s1/2)', 'spinup': 0.15000000000000008, 'spindown': 0.15000000000000008}]
# started fleur calc with pk: 155353
# 0.10000000000000007 2.1999999999999993
# [{'state': '(4s1/2)', 'spinup': 0.10000000000000007, 'spindown': 0.10000000000000007}]
# started fleur calc with pk: 155358
# 0.05000000000000007 2.224999999999999
# [{'state': '(4s1/2)', 'spinup': 0.05000000000000007, 'spindown': 0.05000000000000007}]
# started fleur calc with pk: 155363
# {'lo': [{'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Cobalt (Co)', 'element': 'Co', 'mtSphere': {'radius': 2.37, 'gridPoints': 783, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 27, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)'], 'valenceConfig': ['(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 1.4, 'spinDown': 1.4}, {'state': '(3d5/2)', 'spinUp': 2.9, 'spinDown': 1.3}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Calcium (Ca)', 'element': 'Ca', 'mtSphere': {'radius': 2.8, 'gridPoints': 925, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 20, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# [1] ['(4s1/2)']
# 1 2
# [{'state': '(4s1/2)', 'spinup': 1, 'spindown': 1}]
# started fleur calc with pk: 155371
# 0.95 2.025
# [{'state': '(4s1/2)', 'spinup': 0.95, 'spindown': 0.95}]
# started fleur calc with pk: 155377
# 0.8999999999999999 2.05
# [{'state': '(4s1/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155382
# 0.8499999999999999 2.0749999999999997
# [{'state': '(4s1/2)', 'spinup': 0.8499999999999999, 'spindown': 0.8499999999999999}]
# started fleur calc with pk: 155387
# 0.7999999999999998 2.0999999999999996
# [{'state': '(4s1/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155392
# 0.7499999999999998 2.1249999999999996
# [{'state': '(4s1/2)', 'spinup': 0.7499999999999998, 'spindown': 0.7499999999999998}]
# started fleur calc with pk: 155396
# 0.6999999999999997 2.1499999999999995
# [{'state': '(4s1/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155400
# 0.6499999999999997 2.1749999999999994
# [{'state': '(4s1/2)', 'spinup': 0.6499999999999997, 'spindown': 0.6499999999999997}]
# started fleur calc with pk: 155404
# 0.5999999999999996 2.1999999999999993
# [{'state': '(4s1/2)', 'spinup': 0.5999999999999996, 'spindown': 0.5999999999999996}]
# started fleur calc with pk: 155408
# 0.5499999999999996 2.224999999999999
# [{'state': '(4s1/2)', 'spinup': 0.5499999999999996, 'spindown': 0.5499999999999996}]
# started fleur calc with pk: 155412
# {'name': 'Carbon (C)', 'element': 'C', 'mtSphere': {'radius': 1.79, 'gridPoints': 593, 'logIncrement': 0.018}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 6, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.33333333, 'spinDown': 0.33333333}, {'state': '(2p3/2)', 'spinUp': 0.66666667, 'spinDown': 0.66666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# ['(2p1/2)', '(2p3/2)'] 2
# [0.33333333, 0.66666667] ['(2p1/2)', '(2p3/2)']
# 1.0 2
# [{'state': '(2p1/2)', 'spinup': 0.33333333, 'spindown': 0.33333333}, {'state': '(2p3/2)', 'spinup': 0.66666667, 'spindown': 0.66666667}]
# started fleur calc with pk: 155419
# 0.95 2.025
# [{'state': '(2p1/2)', 'spinup': 0.31666666349999995, 'spindown': 0.31666666349999995}, {'state': '(2p3/2)', 'spinup': 0.6333333365, 'spindown': 0.6333333365}]
# started fleur calc with pk: 155423
# 0.8999999999999999 2.05
# [{'state': '(2p1/2)', 'spinup': 0.29999999699999996, 'spindown': 0.29999999699999996}, {'state': '(2p3/2)', 'spinup': 0.600000003, 'spindown': 0.600000003}]
# started fleur calc with pk: 155427
# 0.8499999999999999 2.0749999999999997
# [{'state': '(2p1/2)', 'spinup': 0.2833333304999999, 'spindown': 0.2833333304999999}, {'state': '(2p3/2)', 'spinup': 0.5666666694999999, 'spindown': 0.5666666694999999}]
# started fleur calc with pk: 155431
# 0.7999999999999998 2.0999999999999996
# [{'state': '(2p1/2)', 'spinup': 0.26666666399999994, 'spindown': 0.26666666399999994}, {'state': '(2p3/2)', 'spinup': 0.5333333359999999, 'spindown': 0.5333333359999999}]
# started fleur calc with pk: 155435
# 0.7499999999999998 2.1249999999999996
# [{'state': '(2p1/2)', 'spinup': 0.2499999974999999, 'spindown': 0.2499999974999999}, {'state': '(2p3/2)', 'spinup': 0.5000000024999999, 'spindown': 0.5000000024999999}]
# started fleur calc with pk: 155439
# 0.6999999999999997 2.1499999999999995
# [{'state': '(2p1/2)', 'spinup': 0.2333333309999999, 'spindown': 0.2333333309999999}, {'state': '(2p3/2)', 'spinup': 0.4666666689999998, 'spindown': 0.4666666689999998}]
# started fleur calc with pk: 155443
# 0.6499999999999997 2.1749999999999994
# [{'state': '(2p1/2)', 'spinup': 0.21666666449999988, 'spindown': 0.21666666449999988}, {'state': '(2p3/2)', 'spinup': 0.4333333354999998, 'spindown': 0.4333333354999998}]
# started fleur calc with pk: 155447
# 0.5999999999999996 2.1999999999999993
# [{'state': '(2p1/2)', 'spinup': 0.19999999799999987, 'spindown': 0.19999999799999987}, {'state': '(2p3/2)', 'spinup': 0.4000000019999998, 'spindown': 0.4000000019999998}]
# started fleur calc with pk: 155451
# 0.5499999999999996 2.224999999999999
# [{'state': '(2p1/2)', 'spinup': 0.18333333149999986, 'spindown': 0.18333333149999986}, {'state': '(2p3/2)', 'spinup': 0.36666666849999974, 'spindown': 0.36666666849999974}]
# started fleur calc with pk: 155456
# {'name': 'Sulfur (S)', 'element': 'S', 'mtSphere': {'radius': 2.28, 'gridPoints': 753, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 16, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'], 'stateOccupation': [{'state': '(3p1/2)', 'spinUp': 0.66666667, 'spinDown': 0.66666667}, {'state': '(3p3/2)', 'spinUp': 1.33333333, 'spinDown': 1.33333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3p1/2)', '(3p3/2)'] 2
# [0.333333335, 0.666666665] ['(3p1/2)', '(3p3/2)']
# 2.0 2
# [{'state': '(3p1/2)', 'spinup': 0.66666667, 'spindown': 0.66666667}, {'state': '(3p3/2)', 'spinup': 1.33333333, 'spindown': 1.33333333}]
# started fleur calc with pk: 155463
# 1.95 2.025
# [{'state': '(3p1/2)', 'spinup': 0.65000000325, 'spindown': 0.65000000325}, {'state': '(3p3/2)', 'spinup': 1.29999999675, 'spindown': 1.29999999675}]
# started fleur calc with pk: 155467
# 1.9 2.05
# [{'state': '(3p1/2)', 'spinup': 0.6333333365, 'spindown': 0.6333333365}, {'state': '(3p3/2)', 'spinup': 1.2666666635000001, 'spindown': 1.2666666635000001}]
# started fleur calc with pk: 155472
# 1.8499999999999999 2.0749999999999997
# [{'state': '(3p1/2)', 'spinup': 0.61666666975, 'spindown': 0.61666666975}, {'state': '(3p3/2)', 'spinup': 1.23333333025, 'spindown': 1.23333333025}]
# started fleur calc with pk: 155476
# 1.7999999999999998 2.0999999999999996
# [{'state': '(3p1/2)', 'spinup': 0.600000003, 'spindown': 0.600000003}, {'state': '(3p3/2)', 'spinup': 1.199999997, 'spindown': 1.199999997}]
# started fleur calc with pk: 155480
# 1.7499999999999998 2.1249999999999996
# [{'state': '(3p1/2)', 'spinup': 0.58333333625, 'spindown': 0.58333333625}, {'state': '(3p3/2)', 'spinup': 1.1666666637499998, 'spindown': 1.1666666637499998}]
# started fleur calc with pk: 155484
# 1.6999999999999997 2.1499999999999995
# [{'state': '(3p1/2)', 'spinup': 0.5666666694999999, 'spindown': 0.5666666694999999}, {'state': '(3p3/2)', 'spinup': 1.1333333305, 'spindown': 1.1333333305}]
# started fleur calc with pk: 155491
# 1.6499999999999997 2.1749999999999994
# [{'state': '(3p1/2)', 'spinup': 0.5500000027499999, 'spindown': 0.5500000027499999}, {'state': '(3p3/2)', 'spinup': 1.0999999972499999, 'spindown': 1.0999999972499999}]
# started fleur calc with pk: 155495
# 1.5999999999999996 2.1999999999999993
# [{'state': '(3p1/2)', 'spinup': 0.5333333359999999, 'spindown': 0.5333333359999999}, {'state': '(3p3/2)', 'spinup': 1.0666666639999998, 'spindown': 1.0666666639999998}]
# started fleur calc with pk: 155500
# 1.5499999999999996 2.224999999999999
# [{'state': '(3p1/2)', 'spinup': 0.5166666692499999, 'spindown': 0.5166666692499999}, {'state': '(3p3/2)', 'spinup': 1.03333333075, 'spindown': 1.03333333075}]
# started fleur calc with pk: 155504
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Vanadium (V)', 'element': 'V', 'mtSphere': {'radius': 2.41, 'gridPoints': 797, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 23, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 0.6, 'spinDown': 0.6}, {'state': '(3d5/2)', 'spinUp': 0.9, 'spinDown': 0.9}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# ['(3d3/2)', '(3d5/2)'] 2
# [0.39999999999999997, 0.6] ['(3d3/2)', '(3d5/2)']
# 1.5 2
# [{'state': '(3d3/2)', 'spinup': 0.6, 'spindown': 0.6}, {'state': '(3d5/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155516
# 1.45 2.025
# [{'state': '(3d3/2)', 'spinup': 0.58, 'spindown': 0.58}, {'state': '(3d5/2)', 'spinup': 0.87, 'spindown': 0.87}]
# started fleur calc with pk: 155522
# 1.4 2.05
# [{'state': '(3d3/2)', 'spinup': 0.5599999999999999, 'spindown': 0.5599999999999999}, {'state': '(3d5/2)', 'spinup': 0.84, 'spindown': 0.84}]
# started fleur calc with pk: 155526
# 1.3499999999999999 2.0749999999999997
# [{'state': '(3d3/2)', 'spinup': 0.5399999999999999, 'spindown': 0.5399999999999999}, {'state': '(3d5/2)', 'spinup': 0.8099999999999999, 'spindown': 0.8099999999999999}]
# started fleur calc with pk: 155530
# 1.2999999999999998 2.0999999999999996
# [{'state': '(3d3/2)', 'spinup': 0.5199999999999999, 'spindown': 0.5199999999999999}, {'state': '(3d5/2)', 'spinup': 0.7799999999999999, 'spindown': 0.7799999999999999}]
# started fleur calc with pk: 155534
# 1.2499999999999998 2.1249999999999996
# [{'state': '(3d3/2)', 'spinup': 0.4999999999999999, 'spindown': 0.4999999999999999}, {'state': '(3d5/2)', 'spinup': 0.7499999999999999, 'spindown': 0.7499999999999999}]
# started fleur calc with pk: 155539
# 1.1999999999999997 2.1499999999999995
# [{'state': '(3d3/2)', 'spinup': 0.47999999999999987, 'spindown': 0.47999999999999987}, {'state': '(3d5/2)', 'spinup': 0.7199999999999999, 'spindown': 0.7199999999999999}]
# started fleur calc with pk: 155545
# 1.1499999999999997 2.1749999999999994
# [{'state': '(3d3/2)', 'spinup': 0.45999999999999985, 'spindown': 0.45999999999999985}, {'state': '(3d5/2)', 'spinup': 0.6899999999999998, 'spindown': 0.6899999999999998}]
# started fleur calc with pk: 155549
# 1.0999999999999996 2.1999999999999993
# [{'state': '(3d3/2)', 'spinup': 0.43999999999999984, 'spindown': 0.43999999999999984}, {'state': '(3d5/2)', 'spinup': 0.6599999999999998, 'spindown': 0.6599999999999998}]
# started fleur calc with pk: 155553
# 1.0499999999999996 2.224999999999999
# [{'state': '(3d3/2)', 'spinup': 0.4199999999999998, 'spindown': 0.4199999999999998}, {'state': '(3d5/2)', 'spinup': 0.6299999999999998, 'spindown': 0.6299999999999998}]
# started fleur calc with pk: 155557
# {'name': 'Phosphorous (P)', 'element': 'P', 'mtSphere': {'radius': 2.43, 'gridPoints': 803, 'logIncrement': 0.015}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 15, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'], 'stateOccupation': [{'state': '(3p1/2)', 'spinUp': 0.5, 'spinDown': 0.5}, {'state': '(3p3/2)', 'spinUp': 1.0, 'spinDown': 1.0}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3p1/2)', '(3p3/2)'] 2
# [0.3333333333333333, 0.6666666666666666] ['(3p1/2)', '(3p3/2)']
# 1.5 2
# [{'state': '(3p1/2)', 'spinup': 0.5, 'spindown': 0.5}, {'state': '(3p3/2)', 'spinup': 1.0, 'spindown': 1.0}]
# started fleur calc with pk: 155566
# 1.45 2.025
# [{'state': '(3p1/2)', 'spinup': 0.4833333333333333, 'spindown': 0.4833333333333333}, {'state': '(3p3/2)', 'spinup': 0.9666666666666666, 'spindown': 0.9666666666666666}]
# started fleur calc with pk: 155571
# 1.4 2.05
# [{'state': '(3p1/2)', 'spinup': 0.4666666666666666, 'spindown': 0.4666666666666666}, {'state': '(3p3/2)', 'spinup': 0.9333333333333332, 'spindown': 0.9333333333333332}]
# started fleur calc with pk: 155575
# 1.3499999999999999 2.0749999999999997
# [{'state': '(3p1/2)', 'spinup': 0.44999999999999996, 'spindown': 0.44999999999999996}, {'state': '(3p3/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155579
# 1.2999999999999998 2.0999999999999996
# [{'state': '(3p1/2)', 'spinup': 0.43333333333333324, 'spindown': 0.43333333333333324}, {'state': '(3p3/2)', 'spinup': 0.8666666666666665, 'spindown': 0.8666666666666665}]
# started fleur calc with pk: 155583
# 1.2499999999999998 2.1249999999999996
# [{'state': '(3p1/2)', 'spinup': 0.4166666666666666, 'spindown': 0.4166666666666666}, {'state': '(3p3/2)', 'spinup': 0.8333333333333331, 'spindown': 0.8333333333333331}]
# started fleur calc with pk: 155588
# 1.1999999999999997 2.1499999999999995
# [{'state': '(3p1/2)', 'spinup': 0.3999999999999999, 'spindown': 0.3999999999999999}, {'state': '(3p3/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155593
# 1.1499999999999997 2.1749999999999994
# [{'state': '(3p1/2)', 'spinup': 0.3833333333333332, 'spindown': 0.3833333333333332}, {'state': '(3p3/2)', 'spinup': 0.7666666666666664, 'spindown': 0.7666666666666664}]
# started fleur calc with pk: 155598
# 1.0999999999999996 2.1999999999999993
# [{'state': '(3p1/2)', 'spinup': 0.36666666666666653, 'spindown': 0.36666666666666653}, {'state': '(3p3/2)', 'spinup': 0.7333333333333331, 'spindown': 0.7333333333333331}]
# started fleur calc with pk: 155602
# 1.0499999999999996 2.224999999999999
# [{'state': '(3p1/2)', 'spinup': 0.34999999999999987, 'spindown': 0.34999999999999987}, {'state': '(3p3/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155606
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Potassium (K)', 'element': 'K', 'mtSphere': {'radius': 2.8, 'gridPoints': 925, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 19, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)'], 'stateOccupation': [{'state': '(4s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# ['(4s1/2)'] 1
# [1.0] ['(4s1/2)']
# 0.5 2
# [{'state': '(4s1/2)', 'spinup': 0.5, 'spindown': 0.5}]
# started fleur calc with pk: 155614
# 0.45 2.025
# [{'state': '(4s1/2)', 'spinup': 0.45, 'spindown': 0.45}]
# started fleur calc with pk: 155619
# 0.4 2.05
# [{'state': '(4s1/2)', 'spinup': 0.4, 'spindown': 0.4}]
# started fleur calc with pk: 155624
# 0.35000000000000003 2.0749999999999997
# [{'state': '(4s1/2)', 'spinup': 0.35000000000000003, 'spindown': 0.35000000000000003}]
# started fleur calc with pk: 155628
# 0.30000000000000004 2.0999999999999996
# [{'state': '(4s1/2)', 'spinup': 0.30000000000000004, 'spindown': 0.30000000000000004}]
# started fleur calc with pk: 155633
# 0.25000000000000006 2.1249999999999996
# [{'state': '(4s1/2)', 'spinup': 0.25000000000000006, 'spindown': 0.25000000000000006}]
# started fleur calc with pk: 155639
# 0.20000000000000007 2.1499999999999995
# [{'state': '(4s1/2)', 'spinup': 0.20000000000000007, 'spindown': 0.20000000000000007}]
# started fleur calc with pk: 155645
# 0.15000000000000008 2.1749999999999994
# [{'state': '(4s1/2)', 'spinup': 0.15000000000000008, 'spindown': 0.15000000000000008}]
# started fleur calc with pk: 155652
# 0.10000000000000007 2.1999999999999993
# [{'state': '(4s1/2)', 'spinup': 0.10000000000000007, 'spindown': 0.10000000000000007}]
# started fleur calc with pk: 155657
# 0.05000000000000007 2.224999999999999
# [{'state': '(4s1/2)', 'spinup': 0.05000000000000007, 'spindown': 0.05000000000000007}]
# started fleur calc with pk: 155662
# {'lo': [{'l': 0, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 3, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Manganese (Mn)', 'element': 'Mn', 'mtSphere': {'radius': 2.35, 'gridPoints': 777, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 25, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)'], 'stateOccupation': [{'state': '(3d3/2)', 'spinUp': 1.25, 'spinDown': 0.75}, {'state': '(3d5/2)', 'spinUp': 3.0, 'spinDown': 0.0}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 4, 's': 4}}
# {'name': 'Aluminum (Al)', 'element': 'Al', 'mtSphere': {'radius': 2.41, 'gridPoints': 797, 'logIncrement': 0.014}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 13, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)'], 'valenceConfig': ['(3s1/2)', '(3p1/2)', '(3p3/2)'], 'stateOccupation': [{'state': '(3p1/2)', 'spinUp': 0.16666667, 'spinDown': 0.16666667}, {'state': '(3p3/2)', 'spinUp': 0.33333333, 'spinDown': 0.33333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# ['(3p1/2)', '(3p3/2)'] 2
# [0.33333334, 0.66666666] ['(3p1/2)', '(3p3/2)']
# 0.5 2
# [{'state': '(3p1/2)', 'spinup': 0.16666667, 'spindown': 0.16666667}, {'state': '(3p3/2)', 'spinup': 0.33333333, 'spindown': 0.33333333}]
# started fleur calc with pk: 155674
# 0.45 2.025
# [{'state': '(3p1/2)', 'spinup': 0.150000003, 'spindown': 0.150000003}, {'state': '(3p3/2)', 'spinup': 0.299999997, 'spindown': 0.299999997}]
# started fleur calc with pk: 155679
# 0.4 2.05
# [{'state': '(3p1/2)', 'spinup': 0.133333336, 'spindown': 0.133333336}, {'state': '(3p3/2)', 'spinup': 0.266666664, 'spindown': 0.266666664}]
# started fleur calc with pk: 155684
# 0.35000000000000003 2.0749999999999997
# [{'state': '(3p1/2)', 'spinup': 0.116666669, 'spindown': 0.116666669}, {'state': '(3p3/2)', 'spinup': 0.233333331, 'spindown': 0.233333331}]
# started fleur calc with pk: 155691
# 0.30000000000000004 2.0999999999999996
# [{'state': '(3p1/2)', 'spinup': 0.100000002, 'spindown': 0.100000002}, {'state': '(3p3/2)', 'spinup': 0.199999998, 'spindown': 0.199999998}]
# started fleur calc with pk: 155698
# 0.25000000000000006 2.1249999999999996
# [{'state': '(3p1/2)', 'spinup': 0.08333333500000001, 'spindown': 0.08333333500000001}, {'state': '(3p3/2)', 'spinup': 0.16666666500000002, 'spindown': 0.16666666500000002}]
# started fleur calc with pk: 155703
# 0.20000000000000007 2.1499999999999995
# [{'state': '(3p1/2)', 'spinup': 0.06666666800000001, 'spindown': 0.06666666800000001}, {'state': '(3p3/2)', 'spinup': 0.13333333200000003, 'spindown': 0.13333333200000003}]
# started fleur calc with pk: 155712
# 0.15000000000000008 2.1749999999999994
# [{'state': '(3p1/2)', 'spinup': 0.05000000100000002, 'spindown': 0.05000000100000002}, {'state': '(3p3/2)', 'spinup': 0.09999999900000005, 'spindown': 0.09999999900000005}]
# started fleur calc with pk: 155717
# 0.10000000000000007 2.1999999999999993
# [{'state': '(3p1/2)', 'spinup': 0.03333333400000002, 'spindown': 0.03333333400000002}, {'state': '(3p3/2)', 'spinup': 0.06666666600000004, 'spindown': 0.06666666600000004}]
# started fleur calc with pk: 155724
# 0.05000000000000007 2.224999999999999
# [{'state': '(3p1/2)', 'spinup': 0.016666667000000024, 'spindown': 0.016666667000000024}, {'state': '(3p3/2)', 'spinup': 0.03333333300000005, 'spindown': 0.03333333300000005}]
# started fleur calc with pk: 155728
# {'name': 'Nitrogen (N)', 'element': 'N', 'mtSphere': {'radius': 1.86, 'gridPoints': 615, 'logIncrement': 0.017}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 7, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.5, 'spinDown': 0.5}, {'state': '(2p3/2)', 'spinUp': 1.0, 'spinDown': 1.0}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# ['(2p1/2)', '(2p3/2)'] 2
# [0.3333333333333333, 0.6666666666666666] ['(2p1/2)', '(2p3/2)']
# 1.5 2
# [{'state': '(2p1/2)', 'spinup': 0.5, 'spindown': 0.5}, {'state': '(2p3/2)', 'spinup': 1.0, 'spindown': 1.0}]
# started fleur calc with pk: 155736
# 1.45 2.025
# [{'state': '(2p1/2)', 'spinup': 0.4833333333333333, 'spindown': 0.4833333333333333}, {'state': '(2p3/2)', 'spinup': 0.9666666666666666, 'spindown': 0.9666666666666666}]
# started fleur calc with pk: 155740
# 1.4 2.05
# [{'state': '(2p1/2)', 'spinup': 0.4666666666666666, 'spindown': 0.4666666666666666}, {'state': '(2p3/2)', 'spinup': 0.9333333333333332, 'spindown': 0.9333333333333332}]
# started fleur calc with pk: 155745
# 1.3499999999999999 2.0749999999999997
# [{'state': '(2p1/2)', 'spinup': 0.44999999999999996, 'spindown': 0.44999999999999996}, {'state': '(2p3/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155750
# 1.2999999999999998 2.0999999999999996
# [{'state': '(2p1/2)', 'spinup': 0.43333333333333324, 'spindown': 0.43333333333333324}, {'state': '(2p3/2)', 'spinup': 0.8666666666666665, 'spindown': 0.8666666666666665}]
# started fleur calc with pk: 155754
# 1.2499999999999998 2.1249999999999996
# [{'state': '(2p1/2)', 'spinup': 0.4166666666666666, 'spindown': 0.4166666666666666}, {'state': '(2p3/2)', 'spinup': 0.8333333333333331, 'spindown': 0.8333333333333331}]
# started fleur calc with pk: 155760
# 1.1999999999999997 2.1499999999999995
# [{'state': '(2p1/2)', 'spinup': 0.3999999999999999, 'spindown': 0.3999999999999999}, {'state': '(2p3/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155764
# 1.1499999999999997 2.1749999999999994
# [{'state': '(2p1/2)', 'spinup': 0.3833333333333332, 'spindown': 0.3833333333333332}, {'state': '(2p3/2)', 'spinup': 0.7666666666666664, 'spindown': 0.7666666666666664}]
# started fleur calc with pk: 155770
# 1.0999999999999996 2.1999999999999993
# [{'state': '(2p1/2)', 'spinup': 0.36666666666666653, 'spindown': 0.36666666666666653}, {'state': '(2p3/2)', 'spinup': 0.7333333333333331, 'spindown': 0.7333333333333331}]
# started fleur calc with pk: 155775
# 1.0499999999999996 2.224999999999999
# [{'state': '(2p1/2)', 'spinup': 0.34999999999999987, 'spindown': 0.34999999999999987}, {'state': '(2p3/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155780
# {'lo': [{'l': 0, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}, {'l': 1, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}], 'name': 'Magnesium (Mg)', 'element': 'Mg', 'mtSphere': {'radius': 2.53, 'gridPoints': 837, 'logIncrement': 0.014}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 12, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)']}, 'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}}
# [1] ['(3s1/2)']
# 1 2
# [{'state': '(3s1/2)', 'spinup': 1, 'spindown': 1}]
# started fleur calc with pk: 155788
# 0.95 2.025
# [{'state': '(3s1/2)', 'spinup': 0.95, 'spindown': 0.95}]
# started fleur calc with pk: 155792
# 0.8999999999999999 2.05
# [{'state': '(3s1/2)', 'spinup': 0.8999999999999999, 'spindown': 0.8999999999999999}]
# started fleur calc with pk: 155797
# 0.8499999999999999 2.0749999999999997
# [{'state': '(3s1/2)', 'spinup': 0.8499999999999999, 'spindown': 0.8499999999999999}]
# started fleur calc with pk: 155802
# 0.7999999999999998 2.0999999999999996
# [{'state': '(3s1/2)', 'spinup': 0.7999999999999998, 'spindown': 0.7999999999999998}]
# started fleur calc with pk: 155806
# 0.7499999999999998 2.1249999999999996
# [{'state': '(3s1/2)', 'spinup': 0.7499999999999998, 'spindown': 0.7499999999999998}]
# started fleur calc with pk: 155810
# 0.6999999999999997 2.1499999999999995
# [{'state': '(3s1/2)', 'spinup': 0.6999999999999997, 'spindown': 0.6999999999999997}]
# started fleur calc with pk: 155814
# 0.6499999999999997 2.1749999999999994
# [{'state': '(3s1/2)', 'spinup': 0.6499999999999997, 'spindown': 0.6499999999999997}]
# started fleur calc with pk: 155818
# 0.5999999999999996 2.1999999999999993
# [{'state': '(3s1/2)', 'spinup': 0.5999999999999996, 'spindown': 0.5999999999999996}]
# started fleur calc with pk: 155822
# 0.5499999999999996 2.224999999999999
# [{'state': '(3s1/2)', 'spinup': 0.5499999999999996, 'spindown': 0.5499999999999996}]
# started fleur calc with pk: 155826
# {'name': 'Lithium (Li)', 'element': 'Li', 'mtSphere': {'radius': 2.36, 'gridPoints': 781, 'logIncrement': 0.013}, 'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 3, 'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)'], 'stateOccupation': [{'state': '(2s1/2)', 'spinUp': 0.5, 'spinDown': 0.5}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}
# ['(2s1/2)'] 1
# [1.0] ['(2s1/2)']
# 0.5 2
# [{'state': '(2s1/2)', 'spinup': 0.5, 'spindown': 0.5}]
# started fleur calc with pk: 155833
# 0.45 2.025
# [{'state': '(2s1/2)', 'spinup': 0.45, 'spindown': 0.45}]
# started fleur calc with pk: 155837
# 0.4 2.05
# [{'state': '(2s1/2)', 'spinup': 0.4, 'spindown': 0.4}]
# started fleur calc with pk: 155841
# 0.35000000000000003 2.0749999999999997
# [{'state': '(2s1/2)', 'spinup': 0.35000000000000003, 'spindown': 0.35000000000000003}]
# started fleur calc with pk: 155845
# 0.30000000000000004 2.0999999999999996
# [{'state': '(2s1/2)', 'spinup': 0.30000000000000004, 'spindown': 0.30000000000000004}]
# started fleur calc with pk: 155849
# 0.25000000000000006 2.1249999999999996
# [{'state': '(2s1/2)', 'spinup': 0.25000000000000006, 'spindown': 0.25000000000000006}]
# started fleur calc with pk: 155853
# 0.20000000000000007 2.1499999999999995
# [{'state': '(2s1/2)', 'spinup': 0.20000000000000007, 'spindown': 0.20000000000000007}]
# started fleur calc with pk: 155857
# 0.15000000000000008 2.1749999999999994
# [{'state': '(2s1/2)', 'spinup': 0.15000000000000008, 'spindown': 0.15000000000000008}]
# started fleur calc with pk: 155861
# 0.10000000000000007 2.1999999999999993
# [{'state': '(2s1/2)', 'spinup': 0.10000000000000007, 'spindown': 0.10000000000000007}]
# started fleur calc with pk: 155865
# 0.05000000000000007 2.224999999999999
# [{'state': '(2s1/2)', 'spinup': 0.05000000000000007, 'spindown': 0.05000000000000007}]
# started fleur calc with pk: 155870

# %%
def plot(lis) :
    
    x = []
    y = []
    
    for species in lis[0].inputs.fleurinpdata.inp_dict['atomSpecies']:

        if species['name'] != 'Oxygen (O)':

            X_name = species['name']
    
    
    for node in lis:
        
        if node.is_finished_ok:
    
            y.append( node.outputs.output_parameters.get_dict()['density_convergence'] )
        
            x.append(2 * (node.inputs.fleurinpdata.inp_dict['atomSpecies'][1]['electronConfig']['stateOccupation'][0]['spinUp'] + node.inputs.fleurinpdata.inp_dict['atomSpecies'][1]['electronConfig']['stateOccupation'][1]['spinUp'] ) -4)

    
    plt.plot(x,y, 'x') 
    plt.xlabel('total charge transfer to Oxygen')
    plt.ylabel('distance after 1 iteration')
    plt.title(X_name)
    #plt.savefig('MgO_sc_loop.pdf')
    plt.show()

# %%
for i in res_l:

    plot(i  )

# %%
for i in res:
    
    print(i.is_finished)
# Out:
# True
# True
# True

# %%
for i in res:
    
    print(i.inputs.fleurinpdata.inp_dict['atomSpecies'])
# Out:
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.2, 'spinDown': 0.2}, {'state': '(6d5/2)', 'spinUp': 0.3, 'spinDown': 0.3}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.6666666667, 'spinDown': 0.6666666667}, {'state': '(2p3/2)', 'spinUp': 1.3333333333, 'spinDown': 1.3333333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.18, 'spinDown': 0.18}, {'state': '(6d5/2)', 'spinUp': 0.27, 'spinDown': 0.27}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.7, 'spinDown': 0.7}, {'state': '(2p3/2)', 'spinUp': 1.4, 'spinDown': 1.4}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.16, 'spinDown': 0.16}, {'state': '(6d5/2)', 'spinUp': 0.24, 'spinDown': 0.24}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.7333333333, 'spinDown': 0.7333333333}, {'state': '(2p3/2)', 'spinUp': 1.4666666667, 'spinDown': 1.4666666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.14, 'spinDown': 0.14}, {'state': '(6d5/2)', 'spinUp': 0.21, 'spinDown': 0.21}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.7666666667, 'spinDown': 0.7666666667}, {'state': '(2p3/2)', 'spinUp': 1.5333333333, 'spinDown': 1.5333333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.12, 'spinDown': 0.12}, {'state': '(6d5/2)', 'spinUp': 0.18, 'spinDown': 0.18}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.8, 'spinDown': 0.8}, {'state': '(2p3/2)', 'spinUp': 1.6, 'spinDown': 1.6}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.1, 'spinDown': 0.1}, {'state': '(6d5/2)', 'spinUp': 0.15, 'spinDown': 0.15}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.8333333333, 'spinDown': 0.8333333333}, {'state': '(2p3/2)', 'spinUp': 1.6666666667, 'spinDown': 1.6666666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.08, 'spinDown': 0.08}, {'state': '(6d5/2)', 'spinUp': 0.12, 'spinDown': 0.12}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.8666666667, 'spinDown': 0.8666666667}, {'state': '(2p3/2)', 'spinUp': 1.7333333333, 'spinDown': 1.7333333333}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.06, 'spinDown': 0.06}, {'state': '(6d5/2)', 'spinUp': 0.09, 'spinDown': 0.09}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.9, 'spinDown': 0.9}, {'state': '(2p3/2)', 'spinUp': 1.8, 'spinDown': 1.8}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]
# [{'name': 'Curium (Cm)', 'element': 'Cm', 'mtSphere': {'radius': 2.62, 'gridPoints': 867, 'logIncrement': 0.016}, 'prodBasis': {'lcutm': 4, 'lcutwf': 9, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 96, 'atomicCutoffs': {'lmax': 10, 'lnonsphr': 8}, 'electronConfig': {'coreConfig': ['(1s1/2)', '(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)', '(3p3/2)', '(4s1/2)', '(3d3/2)', '(3d5/2)', '(4p1/2)', '(4p3/2)', '(5s1/2)', '(4d3/2)', '(4d5/2)', '(5p1/2)', '(5p3/2)', '(6s1/2)', '(4f5/2)', '(4f7/2)', '(5d3/2)', '(5d5/2)', '(6p1/2)', '(6p3/2)'], 'valenceConfig': ['(7s1/2)', '(5f5/2)', '(5f7/2)', '(6d3/2)', '(6d5/2)'], 'stateOccupation': [{'state': '(5f5/2)', 'spinUp': 1.5, 'spinDown': 1.5}, {'state': '(5f7/2)', 'spinUp': 2.0, 'spinDown': 2.0}, {'state': '(6d3/2)', 'spinUp': 0.04, 'spinDown': 0.04}, {'state': '(6d5/2)', 'spinUp': 0.06, 'spinDown': 0.06}]}, 'energyParameters': {'d': 6, 'f': 5, 'p': 7, 's': 7}}, {'name': 'Oxygen (O)', 'element': 'O', 'mtSphere': {'radius': 1.64, 'gridPoints': 543, 'logIncrement': 0.02}, 'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'}, 'modInitDen': {'flipSpinPhi': 0.0, 'flipSpinScale': False, 'flipSpinTheta': 0.0}, 'atomicNumber': 8, 'atomicCutoffs': {'lmax': 6, 'lnonsphr': 4}, 'electronConfig': {'coreConfig': ['(1s1/2)'], 'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)'], 'stateOccupation': [{'state': '(2p1/2)', 'spinUp': 0.9333333333, 'spinDown': 0.9333333333}, {'state': '(2p3/2)', 'spinUp': 1.8666666667, 'spinDown': 1.8666666667}]}, 'energyParameters': {'d': 3, 'f': 4, 'p': 2, 's': 2}}]

# %%
from aiida.orm import groups


group = groups.Group(label = 'delete_1')
group.store()
# Out:
# <Group: "delete_1" [type core], of user aiida@localhost>

# %%
group.add_nodes(res)

# %%
def save_group( nodes ):
    
    for species in res_l[0][0].inputs.fleurinpdata.inp_dict['atomSpecies']:

        if species['name'] != 'Oxygen (O)':

            X_name = species['name']
            
    group_label = X_name + ' XO2 '
    
    
    for i in range
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# UniqueViolation: duplicate key value violates unique constraint "db_dbgroup_name_type_12656f33_uniq"
# DETAIL:  Key (label, type_string)=(delete, core) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /opt/aiida-kernel/lib/python3.8/site-packages/aiida/orm/implementation/django/utils.py in save(self)
#      87             try:
# ---> 88                 self._model.save()
#      89             except IntegrityError as exception:
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     742
# --> 743         self.save_base(using=using, force_insert=force_insert,
#     744                        force_update=force_update, update_fields=update_fields)
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     779                 parent_inserted = self._save_parents(cls, using, update_fields)
# --> 780             updated = self._save_table(
#     781                 raw, cls, force_insert or parent_inserted,
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     872             update_pk = meta.auto_field and not pk_set
# --> 873             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     874             if update_pk:
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, update_pk, raw)
#     909         """
# --> 910         return manager._insert([self], fields=fields, return_id=update_pk,
#     911                                using=using, raw=raw)
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/query.py in _insert(self, objs, fields, return_id, raw, using, ignore_conflicts)
#    1185         query.insert_values(fields, objs, raw=raw)
# -> 1186         return query.get_compiler(using=using).execute_sql(return_id)
#    1187     _insert.alters_data = True
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/models/sql/compiler.py in execute_sql(self, return_id)
#    1376             for sql, params in self.as_sql():
# -> 1377                 cursor.execute(sql, params)
#    1378             if not return_id:
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      66     def execute(self, sql, params=None):
# ---> 67         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      68
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      75             executor = functools.partial(wrapper, executor)
# ---> 76         return executor(sql, params, many, context)
#      77
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      88                     self.wrapper.errors_occurred = True
# ---> 89                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      90
#
# /opt/aiida-kernel/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# IntegrityError: duplicate key value violates unique constraint "db_dbgroup_name_type_12656f33_uniq"
# DETAIL:  Key (label, type_string)=(delete, core) already exists.
#
#
# During handling of the above exception, another exception occurred:
#
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_1633449/3160684126.py in <cell line: 1>()
# ----> 1 group.store()
#
# /opt/aiida-kernel/lib/python3.8/site-packages/aiida/orm/groups.py in store(self)
#     176             raise exceptions.StoringNotAllowed('`type_string` is `None` so the group cannot be stored.')
#     177
# --> 178         return super().store()
#     179
#     180     @property
#
# /opt/aiida-kernel/lib/python3.8/site-packages/aiida/orm/entities.py in store(self)
#     274     def store(self):
#     275         """Store the entity."""
# --> 276         self._backend_entity.store()
#     277         return self
#     278
#
# /opt/aiida-kernel/lib/python3.8/site-packages/aiida/orm/implementation/django/groups.py in store(self)
#      97                     # is not automatically propagated to us
#      98                     self._dbmodel.user = self.user.dbmodel
# ---> 99                 self._dbmodel.save()
#     100
#     101         # To allow to do directly g = Group(...).store()
#
# /opt/aiida-kernel/lib/python3.8/site-packages/aiida/orm/implementation/django/utils.py in save(self)
#      88                 self._model.save()
#      89             except IntegrityError as exception:
# ---> 90                 raise exceptions.IntegrityError(str(exception))
#      91
#      92     def _is_mutable_model_field(self, field):
#
# IntegrityError: duplicate key value violates unique constraint "db_dbgroup_name_type_12656f33_uniq"
# DETAIL:  Key (label, type_string)=(delete, core) already exists.
