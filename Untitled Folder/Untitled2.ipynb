# %%
from aiida_fleur.data.fleurinp import FleurinpData
from aiida import load_profile
from aiida.orm import Dict, load_node , load_code
from aiida.engine import submit, run
from aiida_fleur.calculation.fleurinputgen import FleurinputgenCalculation
from aiida.plugins import DataFactory, CalculationFactory
from aiida_fleur.calculation.fleur import FleurCalculation
from aiida_fleur.data.fleurinpmodifier import FleurinpModifier
from itertools import product
import numpy as np
import json
import matplotlib.pyplot as plt
import numpy as np
import random

load_profile()

# %%
inp = load_node(140784)

# %%
inp.inp_dict['atomSpecies']
# Out:
# [{'lo': [{'l': 0, 'n': 2, 'type': 'SCLO', 'eDeriv': 0},
#    {'l': 1, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}],
#   'name': 'Magnesium (Mg)',
#   'element': 'Mg',
#   'mtSphere': {'radius': 2.33, 'gridPoints': 771, 'logIncrement': 0.015},
#   'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'},
#   'modInitDen': {'flipSpinPhi': 0.0,
#    'flipSpinScale': False,
#    'flipSpinTheta': 0.0},
#   'atomicNumber': 12,
#   'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6},
#   'electronConfig': {'coreConfig': ['(1s1/2)'],
#    'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)']},
#   'energyParameters': {'d': 3, 'f': 4, 'p': 3, 's': 3}},
#  {'name': 'Oxygen (O)',
#   'element': 'O',
#   'mtSphere': {'radius': 1.32, 'gridPoints': 437, 'logIncrement': 0.024},
#   'prodBasis': {'lcutm': 4, 'lcutwf': 6, 'select': '4 0 4 2'},
#   'modInitDen': {'flipSpinPhi': 0.0,
#    'flipSpinScale': False,
#    'flipSpinTheta': 0.0},
#   'atomicNumber': 8,
# ...

# %%
mod = FleurinpModifier(inp)

# %%
mod.set_species('Magnesium (Mg)', {'electronConfig' : {'valenceConfig' : ['(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)' , '(3p1/2)'] , 'stateOccupation' : [{'state': '(3p1/2)',
     'spinUp': 0,
     'spinDown': 0}]}} , create = True )

# %%
mod.show(validate = True)
# Out:
# <fleurInput fleurInputVersion="0.33">
#   <comment>
#       A Fleur
#    </comment>
#   <calculationSetup>
#     <cutoffs Kmax="4.50000000" Gmax="13.50000000" GmaxXC="13.50000000" numbands="0"/>
#     <scfLoop itmax="15" minDistance=".00001000" maxIterBroyd="99" imix="Anderson" alpha=".05000000" precondParam="0.0" spinf="2.00000000"/>
#     <coreElectrons ctail="T" frcor="F" kcrel="0" coretail_lmax="0"/>
#     <xcFunctional name="pbe" relativisticCorrections="F"/>
#     <magnetism jspins="1" l_noco="F" l_ss="F">
#       <qss>.0000000000 .0000000000 .0000000000</qss>
#       <mtNocoParams l_mperp="F" l_mtNocoPot="F" l_relaxSQA="F" mag_mixing_scheme="0" mix_RelaxWeightOffD="1.00000000" l_constrained="F" mix_constr="1.00000000"/>
#       <sourceFreeMag l_sourceFree="F" l_scaleMag="F" mag_scale="1.00000000"/>
#     </magnetism>
#     <soc l_soc="F" theta=".00000000" phi=".00000000" spav="F"/>
#     <prodBasis gcutm="4.00000000" tolerance=".00010000" ewaldlambda="3" lexp="16" bands="0"/>
# ...

# %%
inp_new = mod.freeze()

# %%
inp_new
# Out:
# <FleurinpData: uuid: 2ec6259c-9574-4e30-9f72-b7cffc788453 (pk: 141249)>

# %%
load_node(141256).inputs.fleurinpdata.inp_dict['atomSpecies']
# Out:
# [{'lo': [{'l': 0, 'n': 2, 'type': 'SCLO', 'eDeriv': 0},
#    {'l': 1, 'n': 2, 'type': 'SCLO', 'eDeriv': 0}],
#   'name': 'Magnesium (Mg)',
#   'element': 'Mg',
#   'mtSphere': {'radius': 2.33, 'gridPoints': 771, 'logIncrement': 0.015},
#   'prodBasis': {'lcutm': 4, 'lcutwf': 8, 'select': '4 0 4 2'},
#   'modInitDen': {'flipSpinPhi': 0.0,
#    'flipSpinScale': False,
#    'flipSpinTheta': 0.0},
#   'atomicNumber': 12,
#   'atomicCutoffs': {'lmax': 8, 'lnonsphr': 6},
#   'electronConfig': {'coreConfig': ['(1s1/2)'],
#    'valenceConfig': ['(2s1/2)', '(2p1/2)', '(2p3/2)', '(3s1/2)', '(3p1/2)'],
#    'stateOccupation': [{'state': '(2s1/2)',
#      'spinUp': 0.8000071717,
#      'spinDown': 0.8000071717},
#     {'state': '(2p1/2)', 'spinUp': 0.8287032032, 'spinDown': 0.8287032032},
#     {'state': '(2p3/2)', 'spinUp': 1.9999903465, 'spinDown': 1.9999903465},
#     {'state': '(3s1/2)', 'spinUp': 0.9998776665, 'spinDown': 0.9998776665},
# ...

# %%
list(load_node(144984).inputs)
# Out:
# ['code', 'fleurinpdata']
